# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
# !pip install yfinance
import yfinance as yf
# %matplotlib inline

# %%
naz = yf.Ticker("NAZARA.NS")

# %%
naz_share = naz.history(period = "max")
naz_share
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2021-03-30  1990.000000  2024.900024  1592.000000  1592.000000  7491742
# 2021-03-31  1490.000000  1560.800049  1432.000000  1466.300049  3560915
# 2021-04-01  1505.099976  1738.400024  1499.050049  1670.699951  3523089
# 2021-04-05  1650.000000  1713.000000  1611.000000  1651.099976   986802
# 2021-04-06  1669.000000  1680.000000  1626.000000  1635.150024   377626
# ...                 ...          ...          ...          ...      ...
# 2022-03-22  1784.699951  1784.699951  1755.000000  1775.750000    53202
# 2022-03-23  1785.000000  1795.000000  1755.000000  1761.650024    55420
# 2022-03-24  1754.949951  1754.949951  1698.000000  1722.099976   138391
# 2022-03-25  1702.150024  1727.699951  1645.000000  1652.199951   275051
# 2022-03-28  1625.050049  1648.000000  1588.000000  1596.650024   157083
#
#             Dividends  Stock Splits
# Date
# 2021-03-30          0             0
# ...

# %%
zom = yf.Ticker("ZOMATO.NS")

# %%
zom_share = zom.history(period = "max")
zom_share
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-07-23  116.000000  138.899994  115.000000  126.000000  694895290
# 2021-07-26  126.349998  143.750000  125.300003  140.649994  249723854
# 2021-07-27  141.699997  147.800003  127.750000  132.899994  240341900
# 2021-07-28  131.000000  135.000000  123.550003  131.199997  159793731
# 2021-07-29  134.949997  144.000000  132.199997  141.550003  117973089
# ...                ...         ...         ...         ...        ...
# 2022-03-22   80.949997   81.900002   79.300003   81.150002   23798591
# 2022-03-23   82.000000   82.000000   80.199997   80.750000   12522850
# 2022-03-24   80.699997   82.349998   80.050003   80.349998   12996477
# 2022-03-25   81.000000   81.849998   80.250000   80.599998   13585986
# 2022-03-28   80.599998   81.000000   79.150002   79.650002   10021891
#
#             Dividends  Stock Splits
# Date
# 2021-07-23          0             0
# 2021-07-26          0             0
# ...

# %%
cartrade = yf.Ticker("CARTRADE.NS")

# %%
cartrade_share = cartrade.history(period = "max")
cartrade_share
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2021-08-20  1599.800049  1618.000000  1475.000000  1501.050049  11573178
# 2021-08-23  1526.000000  1596.000000  1515.000000  1579.800049   2200048
# 2021-08-24  1584.000000  1584.400024  1525.349976  1536.300049    567358
# 2021-08-25  1535.150024  1547.000000  1465.949951  1476.250000    515692
# 2021-08-26  1476.250000  1486.300049  1425.000000  1428.199951    405762
# ...                 ...          ...          ...          ...       ...
# 2022-03-22   573.750000   587.900024   567.099976   577.650024    185288
# 2022-03-23   580.000000   622.200012   577.549988   613.150024    773590
# 2022-03-24   609.000000   636.000000   603.000000   621.799988    332512
# 2022-03-25   624.500000   647.450012   615.000000   619.000000    326255
# 2022-03-28   619.049988   623.450012   581.549988   601.650024    352006
#
#             Dividends  Stock Splits
# Date
# 2021-08-20          0             0
# ...

# %%
fworks = yf.Ticker("FRSH")

# %%
fworks_share = fworks.history(period = "max")
fworks_share
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2021-09-22  43.250000  48.750000  43.119999  47.549999  20142100          0
# 2021-09-23  47.556999  49.250000  45.549999  47.540001   4258900          0
# 2021-09-24  47.000000  48.380001  46.099998  46.750000   1725300          0
# 2021-09-27  47.338001  47.480000  43.250000  44.049999   1917800          0
# 2021-09-28  43.020000  43.650002  40.050999  42.730000   4647700          0
# ...               ...        ...        ...        ...       ...        ...
# 2022-03-22  19.930000  20.799999  19.629999  20.110001   2198600          0
# 2022-03-23  19.990000  20.600000  19.240000  20.520000   3797300          0
# 2022-03-24  19.500000  19.650000  18.330000  19.559999   6023800          0
# 2022-03-25  19.780001  20.200001  19.049999  20.100000   2536200          0
# 2022-03-28  19.950001  20.889999  19.700001  20.610001   1956039          0
#
#             Stock Splits
# Date
# ...

# %%
nykaa = yf.Ticker("NYKAA.NS")

# %%
nykaa_share = nykaa.history(period = "max")
nykaa_share
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2021-11-10  2018.000000  2248.000000  2000.000000  2205.800049  34324631
# 2021-11-11  2213.699951  2240.699951  2043.750000  2213.550049   7189777
# 2021-11-12  2248.000000  2409.949951  2180.100098  2358.300049   5829703
# 2021-11-15  2261.000000  2332.399902  2185.000000  2282.250000   3455853
# 2021-11-16  2268.000000  2310.000000  2228.000000  2236.750000   1507125
# ...                 ...          ...          ...          ...       ...
# 2022-03-22  1515.300049  1562.199951  1491.849976  1548.750000    663969
# 2022-03-23  1548.750000  1561.449951  1520.099976  1539.449951    307516
# 2022-03-24  1539.949951  1596.750000  1539.449951  1582.750000    608038
# 2022-03-25  1588.000000  1612.000000  1581.000000  1597.650024    417511
# 2022-03-28  1611.150024  1611.150024  1590.099976  1599.599976    360472
#
#             Dividends  Stock Splits
# Date
# 2021-11-10          0             0
# ...

# %%
pbazar = yf.Ticker("POLICYBZR.NS")

# %%
pbazar_share = pbazar.history(period = "max")
pbazar_share
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2021-11-15  1150.000000  1248.900024  1149.000000  1202.300049  36379065
# 2021-11-16  1210.000000  1434.000000  1210.000000  1341.900024  14456023
# 2021-11-17  1350.000000  1470.000000  1342.000000  1447.949951   7068789
# 2021-11-18  1440.000000  1464.800049  1302.550049  1332.349976   5505748
# 2021-11-22  1332.000000  1332.000000  1190.099976  1237.550049   3843305
# ...                 ...          ...          ...          ...       ...
# 2022-03-22   753.799988   753.799988   726.000000   748.950012    311134
# 2022-03-23   756.000000   765.000000   708.950012   713.349976    626050
# 2022-03-24   724.099976   727.000000   714.000000   720.099976    254297
# 2022-03-25   726.750000   726.750000   700.750000   704.700012    324823
# 2022-03-28   710.000000   710.000000   665.299988   688.599976    435275
#
#             Dividends  Stock Splits
# Date
# 2021-11-15          0             0
# ...

# %%
paytm = yf.Ticker("PAYTM.NS")

# %%
paytm_share = paytm.history(period = "max")
paytm_share
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2021-11-18  1950.000000  1955.000000  1560.000000  1560.800049  23955434
# 2021-11-22  1509.000000  1519.000000  1271.000000  1359.599976  25114710
# 2021-11-23  1360.000000  1525.000000  1360.000000  1494.699951  12954174
# 2021-11-24  1503.000000  1785.000000  1502.949951  1752.449951  21541021
# 2021-11-25  1766.699951  1873.699951  1711.099976  1798.750000  13018344
# ...                 ...          ...          ...          ...       ...
# 2022-03-22   565.750000   590.450012   540.349976   544.000000  26111441
# 2022-03-23   552.000000   562.000000   521.000000   524.299988   8888824
# 2022-03-24   522.000000   595.000000   521.099976   574.349976  24014616
# 2022-03-25   577.599976   588.000000   541.150024   546.000000   8790875
# 2022-03-28   552.000000   554.000000   532.799988   535.549988   3745995
#
#             Dividends  Stock Splits
# Date
# 2021-11-18          0             0
# ...

# %%
mmindia = yf.Ticker("MAPMYINDIA.NS")

# %%
mmindia_share = mmindia.history(period = "max")
mmindia_share
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2021-12-21  1560.692569  1585.623760  1279.069809  1389.814209  13396843
# 2021-12-22  1390.163089  1500.857567  1387.769670  1489.189819   2966238
# 2021-12-23  1500.857732  1509.832961  1438.978466  1454.086792   1123807
# 2021-12-24  1437.033800  1449.000771  1386.224083  1426.812012    837499
# 2021-12-27  1415.094384  1465.754612  1398.739499  1448.053467    461438
# ...                 ...          ...          ...          ...       ...
# 2022-03-22  1583.000000  1584.000000  1555.000000  1572.949951    120182
# 2022-03-23  1583.000000  1625.000000  1566.650024  1575.500000    250409
# 2022-03-24  1576.000000  1579.000000  1530.000000  1544.349976    150347
# 2022-03-25  1549.699951  1560.050049  1528.000000  1531.699951     91976
# 2022-03-28  1537.650024  1539.449951  1451.000000  1475.650024    125221
#
#             Dividends  Stock Splits
# Date
# 2021-12-21        0.0             0
# ...

# %%
naz_share['Open'].plot(label = "Nazara Technologies", figsize = (15,7), color = "Black")
zom_share['Open'].plot(label = "Zomato", color = "Blue")
cartrade_share['Open'].plot(label = "Car Trade", color = "Red")
fworks_share['Open'].plot(label = "FreshWorks", color = "Yellow")
nykaa_share['Open'].plot(label = "Nykaa", color = "Green")
pbazar_share['Open'].plot(label = "Policy Bazaar", color = "Brown")
paytm_share['Open'].plot(label = "Paytm", color = "Orange")
mmindia_share['Open'].plot(label = "Map my India", color = "Pink")
plt.title("Opening of new 8 IPOs of 2021 in India")
plt.legend()

# %%
naz_share['Volume'].plot(label = "Nazara Technologies", figsize = (15,7), color = "Black")
zom_share['Volume'].plot(label = "Zomato", color = "Blue")
cartrade_share['Volume'].plot(label = "Car Trade", color = "Red")
fworks_share['Volume'].plot(label = "Fresh Works", color = "Yellow")
nykaa_share['Volume'].plot(label = "Nykaa", color = "Green")
pbazar_share['Volume'].plot(label = "Policy Bazaar", color = "Brown")
paytm_share['Volume'].plot(label = "Paytm", color = "Orange")
mmindia_share['Volume'].plot(label = "Map my India", color = "Pink")
plt.title("Number of shares traded of new 8 IPOs of 2021 in India")
plt.legend()

# %%
naz_share['MarktCap'] = naz_share['Volume'] * naz_share['Open']
zom_share['MarktCap'] = zom_share['Volume'] * zom_share['Open']
cartrade_share['MarktCap'] = cartrade_share['Volume'] * cartrade_share['Open']
fworks_share['MarktCap'] = fworks_share['Volume'] * fworks_share['Open']
nykaa_share['MarktCap'] = nykaa_share['Volume'] * nykaa_share['Open']
pbazar_share['MarktCap'] = pbazar_share['Volume'] * pbazar_share['Open']
paytm_share['MarktCap'] = paytm_share['Volume'] * paytm_share['Open']
mmindia_share['MarktCap'] = mmindia_share['Volume'] * mmindia_share['Open']
naz_share['MarktCap'].plot(label = "Nazara Technologies", figsize = (15,7), color = "Black")
zom_share['MarktCap'].plot(label = "Zomato", color = "Blue")
cartrade_share['MarktCap'].plot(label = "Car Trade", color = "Red")
fworks_share['MarktCap'].plot(label = "Fresh Works", color = "Yellow")
nykaa_share['MarktCap'].plot(label = "Nykaa", color = "Green")
pbazar_share['MarktCap'].plot(label = "Policy Bazaar", color = "Brown")
paytm_share['MarktCap'].plot(label = "Paytm", color = "Orange")
mmindia_share['MarktCap'].plot(label = "Map my India", color = "Pink")
plt.title("Market Cap of new 8 IPOs of 2021 in India")
plt.legend()

# %%
naz_share['MA30'] = naz_share['Open'].rolling(30).mean()
naz_share['Open'].plot(figsize = (15,7))
naz_share['MA30'].plot()
plt.title('Average opening for 30 days for Nazara Technologies')
plt.legend()

# %%
zom_share['MA30'] = zom_share['Open'].rolling(30).mean()
zom_share['Open'].plot(figsize = (15,7))
zom_share['MA30'].plot()
plt.title('Average opening for 30 days for Zomato')
plt.legend()

# %%
cartrade_share['MA30'] = cartrade_share['Open'].rolling(30).mean()
cartrade_share['Open'].plot(figsize = (15,7))
cartrade_share['MA30'].plot()
plt.title('Average opening for 30 days for Car Trade')
plt.legend()

# %%
fworks_share['MA30'] = fworks_share['Open'].rolling(30).mean()
fworks_share['Open'].plot(figsize = (15,7))
fworks_share['MA30'].plot()
plt.title('Average opening for 30 days for FreshWorks')
plt.legend()

# %%
nykaa_share['MA30'] = nykaa_share['Open'].rolling(30).mean()
nykaa_share['Open'].plot(figsize = (15,7))
nykaa_share['MA30'].plot()
plt.title('Average opening for 30 days for Nyka')
plt.legend()

# %%
pbazar_share['MA30'] = pbazar_share['Open'].rolling(30).mean()
pbazar_share['Open'].plot(figsize = (15,7))
pbazar_share['MA30'].plot()
plt.title('Average opening for 30 days for Policy Bazaar')
plt.legend()

# %%
paytm_share['MA30'] = paytm_share['Open'].rolling(30).mean()
paytm_share['Open'].plot(figsize = (15,7))
paytm_share['MA30'].plot()
plt.title('Average opening for 30 days for Paytm')
plt.legend()

# %%
mmindia_share['MA30'] = mmindia_share['Open'].rolling(30).mean()
mmindia_share['Open'].plot(figsize = (15,7))
mmindia_share['MA30'].plot()
plt.title('Average opening for 30 days for Map My India')
plt.legend()

# %%
data = pd.concat([naz_share['Open'], zom_share['Open'], cartrade_share['Open'], fworks_share['Open'], nykaa_share['Open'], pbazar_share['Open'], paytm_share['Open'], mmindia_share['Open']], axis =1)
data.columns = ['Nazara Technologies Open', 'Zomato Open', 'Car Trade Open', 'FreshWorks Open', 'Nykaa Open', 'Policy Bazaar Open', 'Paytm Open', 'Map My India Open']
scatter_matrix(data, figsize = (15,15), hist_kwds = {'bins' : 250})
# Out:
# array([[<AxesSubplot:xlabel='Nazara Technologies Open', ylabel='Nazara Technologies Open'>,
#         <AxesSubplot:xlabel='Zomato Open', ylabel='Nazara Technologies Open'>,
#         <AxesSubplot:xlabel='Car Trade Open', ylabel='Nazara Technologies Open'>,
#         <AxesSubplot:xlabel='FreshWorks Open', ylabel='Nazara Technologies Open'>,
#         <AxesSubplot:xlabel='Nykaa Open', ylabel='Nazara Technologies Open'>,
#         <AxesSubplot:xlabel='Policy Bazaar Open', ylabel='Nazara Technologies Open'>,
#         <AxesSubplot:xlabel='Paytm Open', ylabel='Nazara Technologies Open'>,
#         <AxesSubplot:xlabel='Map My India Open', ylabel='Nazara Technologies Open'>],
#        [<AxesSubplot:xlabel='Nazara Technologies Open', ylabel='Zomato Open'>,
#         <AxesSubplot:xlabel='Zomato Open', ylabel='Zomato Open'>,
#         <AxesSubplot:xlabel='Car Trade Open', ylabel='Zomato Open'>,
#         <AxesSubplot:xlabel='FreshWorks Open', ylabel='Zomato Open'>,
# ...

# %%
naz_share['returns'] = (naz_share['Close']/naz_share['Close'].shift(1)) - 1
zom_share['returns'] = (zom_share['Close']/zom_share['Close'].shift(1)) - 1
cartrade_share['returns'] = (cartrade_share['Close']/cartrade_share['Close'].shift(1)) - 1
fworks_share['returns'] = (fworks_share['Close']/fworks_share['Close'].shift(1)) - 1
nykaa_share['returns'] = (nykaa_share['Close']/nykaa_share['Close'].shift(1)) - 1
pbazar_share['returns'] = (pbazar_share['Close']/pbazar_share['Close'].shift(1)) - 1
paytm_share['returns'] = (paytm_share['Close']/paytm_share['Close'].shift(1)) - 1
mmindia_share['returns'] = (mmindia_share['Close']/mmindia_share['Close'].shift(1)) - 1
naz_share['returns'].hist(bins = 100, label = 'Nazara Technologies', alpha = 0.5, color = "Black", figsize = (15,7))
zom_share['returns'].hist(bins = 100, label = 'Zomato', alpha = 0.5, color = "Blue")
cartrade_share['returns'].hist(bins = 100, label = 'Car Trade', alpha = 0.5, color = "Red")
fworks_share['returns'].hist(bins = 100, label = 'FreshWorks', alpha = 0.5, color = "Yellow")
nykaa_share['returns'].hist(bins = 100, label = 'Nykaa', alpha = 0.5, color = "Green")
pbazar_share['returns'].hist(bins = 100, label = 'Policy Bazaar', alpha = 0.5, color = "Brown")
paytm_share['returns'].hist(bins = 100, label = 'Paytm', alpha = 0.5, color = "Orange")
mmindia_share['returns'].hist(bins = 100, label = 'Map My India', alpha = 0.5, color = "Pink")
plt.legend()
plt.title('percentage Increase in Stocks')
# Out:
# Text(0.5, 1.0, 'percentage Increase in Stocks')
